# %% [markdown]
# <a href="https://colab.research.google.com/github/SubashChan24/Sales_Data_Analysis/blob/main/Sales_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SALES DATA ANALYSIS**

# %% [markdown]
# DATA IMPORT

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_dim_customer=pd.read_csv("/content/dim_customer.csv", encoding='ISO-8859-1')
df_dim_market=pd.read_csv("/content/dim_market (1).csv")
df_dim_product=pd.read_csv("/content/dim_product (1).csv", encoding='ISO-8859-1')
df_fact_sales=pd.read_csv("/content/fact_sales_monthly (1).csv")

# %% [markdown]
# DATA EXPLORE

# %% [markdown]
# df_dim_customer=dim_customer
#
# df_dim_market=dim_market
#
# df_dim_product=dim_product
#
# df_fact_sales=fact_sales_monthly

# %% [markdown]
# Exploring fact table

# %%
df_fact_sales
# Out:
#             date product_code  customer_code  Qty  net_sales_amount
# 0       9/1/2018  A0418150108       90023030  -16            163.98
# 1       9/1/2018  A3019150205       90023023  132            698.85
# 2       9/1/2018  A3019150205       90023030  111            641.68
# 3       9/1/2018  A3019150205       90012041  -59            289.60
# 4       9/1/2018  A3019150205       90014141    4             19.95
# ...          ...          ...            ...  ...               ...
# 799957  8/1/2021  A3019150205       70017060   37            260.80
# 799958  8/1/2021  A3019150205       70007199   66            390.05
# 799959  8/1/2021  A3019150205       70018115  101            507.93
# 799960  8/1/2021  A3019150205       70019204   20            129.95
# 799961  8/1/2021  A3019150205       70021096 -200           1324.23
#
# [799962 rows x 5 columns]

# %%
df_fact_sales.shape
# Out:
# (799962, 5)

# %%
df_fact_sales.head(5)
# Out:
#        date product_code  customer_code  Qty  net_sales_amount
# 0  9/1/2018  A0418150108       90023030  -16            163.98
# 1  9/1/2018  A3019150205       90023023  132            698.85
# 2  9/1/2018  A3019150205       90023030  111            641.68
# 3  9/1/2018  A3019150205       90012041  -59            289.60
# 4  9/1/2018  A3019150205       90014141    4             19.95

# %%
df_fact_sales.tail(5)
# Out:
#             date product_code  customer_code  Qty  net_sales_amount
# 799957  8/1/2021  A3019150205       70017060   37            260.80
# 799958  8/1/2021  A3019150205       70007199   66            390.05
# 799959  8/1/2021  A3019150205       70018115  101            507.93
# 799960  8/1/2021  A3019150205       70019204   20            129.95
# 799961  8/1/2021  A3019150205       70021096 -200           1324.23

# %%
df_fact_sales.columns
# Out:
# Index(['date', 'product_code', 'customer_code', 'Qty', 'net_sales_amount'], dtype='object')

# %%
df_fact_sales.dtypes
# Out:
# date                 object
# product_code         object
# customer_code         int64
# Qty                   int64
# net_sales_amount    float64
# dtype: object

# %% [markdown]
# grouping the table by product code='A3019150205'

# %%
groupby=df_fact_sales.groupby('product_code')
groupby.get_group('A3019150205')
# Out:
#                     date product_code  customer_code  Qty  net_sales_amount
# 1       01-09-2018 00:00  A3019150205       90023023  132            698.85
# 2       01-09-2018 00:00  A3019150205       90023030  111            641.68
# 3       01-09-2018 00:00  A3019150205       90012041  -59            289.60
# 4       01-09-2018 00:00  A3019150205       90014141    4             19.95
# 5       01-09-2018 00:00  A3019150205       90005162   -8             41.78
# ...                  ...          ...            ...  ...               ...
# 799957  01-08-2021 00:00  A3019150205       70017060   37            260.80
# 799958  01-08-2021 00:00  A3019150205       70007199   66            390.05
# 799959  01-08-2021 00:00  A3019150205       70018115  101            507.93
# 799960  01-08-2021 00:00  A3019150205       70019204   20            129.95
# 799961  01-08-2021 00:00  A3019150205       70021096 -200           1324.23
#
# [4702 rows x 5 columns]

# %%
df_fact_sales.isna()
# Out:
#          date  product_code  customer_code    Qty  net_sales_amount
# 0       False         False          False  False             False
# 1       False         False          False  False             False
# 2       False         False          False  False             False
# 3       False         False          False  False             False
# 4       False         False          False  False             False
# ...       ...           ...            ...    ...               ...
# 799957  False         False          False  False             False
# 799958  False         False          False  False             False
# 799959  False         False          False  False             False
# 799960  False         False          False  False             False
# 799961  False         False          False  False             False
#
# [799962 rows x 5 columns]

# %%
df_fact_sales.isna().sum()
# Out:
# date                0
# product_code        0
# customer_code       0
# Qty                 0
# net_sales_amount    0
# dtype: int64

# %% [markdown]
# calculating total sales by multipyling net sales amount and quantity

# %%
total_sales=df_fact_sales['net_sales_amount']*df_fact_sales['Qty']
total_sales
# Out:
# 0          -2623.68
# 1          92248.20
# 2          71226.48
# 3         -17086.40
# 4             79.80
#             ...
# 799957      9649.60
# 799958     25743.30
# 799959     51300.93
# 799960      2599.00
# 799961   -264846.00
# Length: 799962, dtype: float64

# %% [markdown]
# Exploring customer table

# %%
df_dim_customer
# Out:
#      customer_code            customer       market        platform  \
# 0         80001019             Neptune        China  Brick & Mortar
# 1         70003182       Atliq e Store    Indonesia      E-Commerce
# 2         70003181     AltiQ Exclusive    Indonesia  Brick & Mortar
# 3         70007198     AltiQ Exclusive  South Korea  Brick & Mortar
# 4         70007199       Atliq e Store  South Korea      E-Commerce
# ..             ...                 ...          ...             ...
# 184       90002014          Expression        India  Brick & Mortar
# 185       90002011     Atliq Exclusive        India  Brick & Mortar
# 186       90002010                Ebay        India      E-Commerce
# 187       90002013  Electricalslytical        India  Brick & Mortar
# 188       90002012    Electricalsocity        India  Brick & Mortar
#
#          channel
# 0    Distributor
# 1         Direct
# 2         Direct
# 3         Direct
# 4         Direct
# ..           ...
# 184     Retailer
# ...

# %%
df_dim_customer.shape
# Out:
# (189, 5)

# %%
df_dim_customer.head(5)
# Out:
#    customer_code         customer       market        platform      channel
# 0       80001019          Neptune        China  Brick & Mortar  Distributor
# 1       70003182    Atliq e Store    Indonesia      E-Commerce       Direct
# 2       70003181  AltiQ Exclusive    Indonesia  Brick & Mortar       Direct
# 3       70007198  AltiQ Exclusive  South Korea  Brick & Mortar       Direct
# 4       70007199    Atliq e Store  South Korea      E-Commerce       Direct

# %%
df_dim_customer.tail(5)
# Out:
#      customer_code            customer market        platform   channel
# 184       90002014          Expression  India  Brick & Mortar  Retailer
# 185       90002011     Atliq Exclusive  India  Brick & Mortar  Retailer
# 186       90002010                Ebay  India      E-Commerce  Retailer
# 187       90002013  Electricalslytical  India  Brick & Mortar  Retailer
# 188       90002012    Electricalsocity  India  Brick & Mortar  Retailer

# %%
df_dim_customer.columns
# Out:
# Index(['customer_code', 'customer', 'market', 'platform', 'channel'], dtype='object')

# %%
df_dim_customer.dtypes
# Out:
# customer_code     int64
# customer         object
# market           object
# platform         object
# channel          object
# dtype: object

# %%
df_dim_customer.customer.unique()
# Out:
# array(['Neptune', 'Atliq e Store', 'AltiQ Exclusive', 'Sage', 'Leader',
#        'Synthetic', 'Novus', 'Zone', 'Taobao', 'Amazon',
#        'Acclaimed Stores', 'Expert', "Argos (Sainsbury's)", 'Sorefoz',
#        'Nomad Stores', 'Expression', 'Control', 'Surface Stores',
#        'Insight', 'Forward Stores', 'Digimarket', 'Electricalsocity',
#        'Sound', 'Logic Stores', 'Propel', 'Epic Stores', 'Fnac-Darty',
#        'Nova', 'Euronics', 'Atlas Stores', 'Electricalsquipo Stores',
#        'Integration Stores', 'Electricalsara Stores',
#        'Currys (Dixons Carphone)', 'Reliance Digital',
#        'Electricalslance Stores', 'Chiptec', 'Boulanger', 'UniEuro',
#        'Radio Popular', 'Elkjøp', 'Chip 7', 'Elite', 'All-Out',
#        'Info Stores', 'Electricalsbea Stores', 'Flawless Stores',
#        'walmart', 'Costco', 'Staples', 'Relief', 'Premium Stores',
#        'Saturn', 'Otto', 'Notebillig', 'Coolblue', 'Electricalslytical',
# ...

# %%
df_dim_customer.customer.value_counts()
# Out:
# customer
# Amazon                   26
# Atliq e Store            22
# AltiQ Exclusive          16
# Expert                    5
# Euronics                  4
#                          ..
# Electricalsbea Stores     1
# All-Out                   1
# Insight                   1
# Nova                      1
# Atliq Exclusive           1
# Name: count, Length: 68, dtype: int64

# %%
df_dim_customer.market.unique()
# Out:
# array(['China', 'Indonesia', 'South Korea', 'Sweden', 'Pakistan',
#        'Bangladesh', 'Philiphines', 'Australia', 'Newzealand', 'Austria',
#        'Poland', 'Norway', 'Netherlands', 'Japan', 'France', 'Canada',
#        'Germany', 'United Kingdom', 'Spain', 'Italy', 'Portugal', 'USA',
#        'India'], dtype=object)

# %%
df_dim_customer.market.value_counts()
# Out:
# market
# India             18
# USA               13
# United Kingdom    11
# Canada            11
# Japan             10
# Portugal          10
# Italy             10
# Spain             10
# Germany           10
# France             9
# Norway             8
# Austria            8
# Netherlands        7
# Poland             7
# Newzealand         7
# Australia          7
# Philiphines        6
# Bangladesh         5
# Pakistan           5
# Sweden             5
# South Korea        5
# Indonesia          4
# China              3
# Name: count, dtype: int64

# %%
df_dim_customer.platform.unique()
# Out:
# array(['Brick & Mortar', 'E-Commerce'], dtype=object)

# %%
df_dim_customer.platform.value_counts()
# Out:
# platform
# Brick & Mortar    135
# E-Commerce         54
# Name: count, dtype: int64

# %%
df_dim_customer.channel.unique()
# Out:
# array(['Distributor', 'Direct', 'Retailer'], dtype=object)

# %%
df_dim_customer.channel.value_counts()
# Out:
# channel
# Retailer       146
# Direct          38
# Distributor      5
# Name: count, dtype: int64

# %% [markdown]
# grouping the table by customer='Ebay'

# %%
groupby=df_dim_customer.groupby('customer')
groupby.get_group('Ebay')
# Out:
#      customer_code customer market    platform   channel
# 169       90022083     Ebay    USA  E-Commerce  Retailer
# 186       90002010     Ebay  India  E-Commerce  Retailer

# %% [markdown]
# grouping the table by market='india'

# %%
groupby=df_dim_customer.groupby('market')
groupby.get_group('India')
# Out:
#      customer_code            customer market        platform   channel
# 41        70002018       Atliq e Store  India      E-Commerce    Direct
# 42        70002017     AltiQ Exclusive  India  Brick & Mortar    Direct
# 173       90002007              Girias  India  Brick & Mortar  Retailer
# 174       90002006              Viveks  India  Brick & Mortar  Retailer
# 175       90002009            Flipkart  India      E-Commerce  Retailer
# 176       90002008              Amazon  India      E-Commerce  Retailer
# 177       90002005               Lotus  India  Brick & Mortar  Retailer
# 178       90002002               Croma  India  Brick & Mortar  Retailer
# 179       90002001    Reliance Digital  India  Brick & Mortar  Retailer
# 180       90002004         Vijay Sales  India  Brick & Mortar  Retailer
# 181       90002003               Ezone  India  Brick & Mortar  Retailer
# 182       90002016              Amazon  India      E-Commerce  Retailer
# ...

# %% [markdown]
# grouping the table by platform= 'E-commerce'

# %%
groupby=df_dim_customer.groupby('platform')
groupby.get_group('E-Commerce')
# Out:
#      customer_code       customer          market    platform   channel
# 1         70003182  Atliq e Store       Indonesia  E-Commerce    Direct
# 4         70007199  Atliq e Store     South Korea  E-Commerce    Direct
# 5         70019204  Atliq e Store          Sweden  E-Commerce    Direct
# 6         70005163  Atliq e Store        Pakistan  E-Commerce    Direct
# 8         70010048  Atliq e Store      Bangladesh  E-Commerce    Direct
# 13        70006158  Atliq e Store     Philiphines  E-Commerce    Direct
# 16        70008170  Atliq e Store       Australia  E-Commerce    Direct
# 17        70009134  Atliq e Store      Newzealand  E-Commerce    Direct
# 18        70020104  Atliq e Store         Austria  E-Commerce    Direct
# 20        70016178  Atliq e Store          Poland  E-Commerce    Direct
# 23        70015152  Atliq e Store          Norway  E-Commerce    Direct
# 24        70014143  Atliq e Store     Netherlands  E-Commerce    Direct
# ...

# %% [markdown]
# grouping the table by channel='direct'

# %%
groupby=df_dim_customer.groupby('channel')
groupby.get_group('Direct')
# Out:
#     customer_code         customer          market        platform channel
# 1        70003182    Atliq e Store       Indonesia      E-Commerce  Direct
# 2        70003181  AltiQ Exclusive       Indonesia  Brick & Mortar  Direct
# 3        70007198  AltiQ Exclusive     South Korea  Brick & Mortar  Direct
# 4        70007199    Atliq e Store     South Korea      E-Commerce  Direct
# 5        70019204    Atliq e Store          Sweden      E-Commerce  Direct
# 6        70005163    Atliq e Store        Pakistan      E-Commerce  Direct
# 7        70010047  AltiQ Exclusive      Bangladesh  Brick & Mortar  Direct
# 8        70010048    Atliq e Store      Bangladesh      E-Commerce  Direct
# 13       70006158    Atliq e Store     Philiphines      E-Commerce  Direct
# 14       70006157  AltiQ Exclusive     Philiphines  Brick & Mortar  Direct
# 15       70008169  AltiQ Exclusive       Australia  Brick & Mortar  Direct
# ...

# %%
df_dim_customer.isna()
# Out:
#      customer_code  customer  market  platform  channel
# 0            False     False   False     False    False
# 1            False     False   False     False    False
# 2            False     False   False     False    False
# 3            False     False   False     False    False
# 4            False     False   False     False    False
# ..             ...       ...     ...       ...      ...
# 184          False     False   False     False    False
# 185          False     False   False     False    False
# 186          False     False   False     False    False
# 187          False     False   False     False    False
# 188          False     False   False     False    False
#
# [189 rows x 5 columns]

# %%
df_dim_customer.isna().sum()
# Out:
# customer_code    0
# customer         0
# market           0
# platform         0
# channel          0
# dtype: int64

# %% [markdown]
# Exploring market table

# %%
df_dim_market
# Out:
#             market sub_zone region
# 0           Canada      NaN    NaN
# 1              USA      NaN    NaN
# 2   United Kingdom       NE     EU
# 3          Austria       NE     EU
# 4           Sweden       NE     EU
# 5            Spain       SE     EU
# 6         Portugal       SE     EU
# 7           Poland       NE     EU
# 8           Norway       NE     EU
# 9      Netherlands       NE     EU
# 10           Italy       SE     EU
# 11         Germany       NE     EU
# 12          France       SE     EU
# 13      Bangladesh      ROA   APAC
# 14      Newzealand      ANZ   APAC
# 15       Australia      ANZ   APAC
# 16     South Korea      ROA   APAC
# 17     Philiphines      ROA   APAC
# 18        Pakistan      ROA   APAC
# 19           Japan      ROA   APAC
# 20       Indonesia      ROA   APAC
# 21           India    India   APAC
# 22           China      ROA   APAC

# %%
df_dim_market.shape
# Out:
# (23, 3)

# %%
df_dim_market.head(5)
# Out:
#            market sub_zone region
# 0          Canada      NaN    NaN
# 1             USA      NaN    NaN
# 2  United Kingdom       NE     EU
# 3         Austria       NE     EU
# 4          Sweden       NE     EU

# %%
df_dim_market.tail(5)
# Out:
#        market sub_zone region
# 18   Pakistan      ROA   APAC
# 19      Japan      ROA   APAC
# 20  Indonesia      ROA   APAC
# 21      India    India   APAC
# 22      China      ROA   APAC

# %%
df_dim_market.columns
# Out:
# Index(['market', 'sub_zone', 'region'], dtype='object')

# %%
df_dim_market.dtypes
# Out:
# market      object
# sub_zone    object
# region      object
# dtype: object

# %%
df_dim_market.market.unique()
# Out:
# array(['Canada', 'USA', 'United Kingdom', 'Austria', 'Sweden', 'Spain',
#        'Portugal', 'Poland', 'Norway', 'Netherlands', 'Italy', 'Germany',
#        'France', 'Bangladesh', 'Newzealand', 'Australia', 'South Korea',
#        'Philiphines', 'Pakistan', 'Japan', 'Indonesia', 'India', 'China'],
#       dtype=object)

# %%
df_dim_market.market.value_counts()
# Out:
# market
# Canada            1
# France            1
# India             1
# Indonesia         1
# Japan             1
# Pakistan          1
# Philiphines       1
# South Korea       1
# Australia         1
# Newzealand        1
# Bangladesh        1
# Germany           1
# USA               1
# Italy             1
# Netherlands       1
# Norway            1
# Poland            1
# Portugal          1
# Spain             1
# Sweden            1
# Austria           1
# United Kingdom    1
# China             1
# Name: count, dtype: int64

# %%
df_dim_market.sub_zone.unique()
# Out:
# array([nan, 'NE', 'SE', 'ROA', 'ANZ', 'India'], dtype=object)

# %%
df_dim_market.sub_zone.value_counts()
# Out:
# sub_zone
# NE       7
# ROA      7
# SE       4
# ANZ      2
# India    1
# Name: count, dtype: int64

# %%
df_dim_market.region.unique()
# Out:
# array([nan, 'EU', 'APAC'], dtype=object)

# %%
df_dim_market.region.value_counts()
# Out:
# region
# EU      11
# APAC    10
# Name: count, dtype: int64

# %% [markdown]
# grouping the table by market='USA'

# %%
groupby=df_dim_market.groupby('market')
groupby.get_group('USA')
# Out:
#   market sub_zone region
# 1    USA      NaN    NaN

# %% [markdown]
# grouping the table by sub zone='NE'

# %%
groupby=df_dim_market.groupby('sub_zone')
groupby.get_group('NE')
# Out:
#             market sub_zone region
# 2   United Kingdom       NE     EU
# 3          Austria       NE     EU
# 4           Sweden       NE     EU
# 7           Poland       NE     EU
# 8           Norway       NE     EU
# 9      Netherlands       NE     EU
# 11         Germany       NE     EU

# %%
groupby=df_dim_market.groupby('region')
groupby.get_group('EU')
# Out:
#             market sub_zone region
# 2   United Kingdom       NE     EU
# 3          Austria       NE     EU
# 4           Sweden       NE     EU
# 5            Spain       SE     EU
# 6         Portugal       SE     EU
# 7           Poland       NE     EU
# 8           Norway       NE     EU
# 9      Netherlands       NE     EU
# 10           Italy       SE     EU
# 11         Germany       NE     EU
# 12          France       SE     EU

# %%
df_dim_market.isna()
# Out:
#     market  sub_zone  region
# 0    False      True    True
# 1    False      True    True
# 2    False     False   False
# 3    False     False   False
# 4    False     False   False
# 5    False     False   False
# 6    False     False   False
# 7    False     False   False
# 8    False     False   False
# 9    False     False   False
# 10   False     False   False
# 11   False     False   False
# 12   False     False   False
# 13   False     False   False
# 14   False     False   False
# 15   False     False   False
# 16   False     False   False
# 17   False     False   False
# 18   False     False   False
# 19   False     False   False
# 20   False     False   False
# 21   False     False   False
# 22   False     False   False

# %%
df_dim_market.isna().sum()
# Out:
# market      0
# sub_zone    2
# region      2
# dtype: int64

# %% [markdown]
# Exploring product table

# %%
df_dim_product
# Out:
#     product_code division      segment       category                product  \
# 0    A5721110508       PC     Notebook  Gaming Laptop             AQ Smash 2
# 1    A5721110507       PC     Notebook  Gaming Laptop             AQ Smash 2
# 2    A5721110505       PC     Notebook  Gaming Laptop             AQ Smash 2
# 3    A5721110504       PC     Notebook  Gaming Laptop             AQ Smash 2
# 4    A5721110503       PC     Notebook  Gaming Laptop             AQ Smash 2
# ..           ...      ...          ...            ...                    ...
# 293  A2118150106    P & A  Accessories          Mouse  AQ Master wired x1 Ms
# 294  A2118150105    P & A  Accessories          Mouse  AQ Master wired x1 Ms
# 295  A2118150104    P & A  Accessories          Mouse  AQ Master wired x1 Ms
# 296  A2118150102    P & A  Accessories          Mouse  AQ Master wired x1 Ms
# 297  A2118150101    P & A  Accessories          Mouse  AQ Master wired x1 Ms
#
#                  variant
# ...

# %%
df_dim_product.shape
# Out:
# (298, 6)

# %%
df_dim_product.head(5)
# Out:
#   product_code division   segment       category     product  \
# 0  A5721110508       PC  Notebook  Gaming Laptop  AQ Smash 2
# 1  A5721110507       PC  Notebook  Gaming Laptop  AQ Smash 2
# 2  A5721110505       PC  Notebook  Gaming Laptop  AQ Smash 2
# 3  A5721110504       PC  Notebook  Gaming Laptop  AQ Smash 2
# 4  A5721110503       PC  Notebook  Gaming Laptop  AQ Smash 2
#
#                variant
# 0  Premium Misty Green
# 1        Premium Black
# 2       Plus Cool Blue
# 3       Plus Firey Red
# 4       Standard Black

# %%
df_dim_product.tail(5)
# Out:
#     product_code division      segment category                product  \
# 293  A2118150106    P & A  Accessories    Mouse  AQ Master wired x1 Ms
# 294  A2118150105    P & A  Accessories    Mouse  AQ Master wired x1 Ms
# 295  A2118150104    P & A  Accessories    Mouse  AQ Master wired x1 Ms
# 296  A2118150102    P & A  Accessories    Mouse  AQ Master wired x1 Ms
# 297  A2118150101    P & A  Accessories    Mouse  AQ Master wired x1 Ms
#
#         variant
# 293   Premium 2
# 294   Premium 1
# 295      Plus 2
# 296  Standard 2
# 297  Standard 1

# %%
df_dim_product.columns
# Out:
# Index(['product_code', 'division', 'segment', 'category', 'product',
#        'variant'],
#       dtype='object')

# %%
df_dim_product.dtypes
# Out:
# product_code    object
# division        object
# segment         object
# category        object
# product         object
# variant         object
# dtype: object

# %%
df_dim_product.division.unique()
# Out:
# array(['PC', 'N & S', 'P & A'], dtype=object)

# %%
df_dim_product.division.value_counts()
# Out:
# division
# P & A    162
# PC       100
# N & S     36
# Name: count, dtype: int64

# %%
df_dim_product.segment.unique()
# Out:
# array(['Notebook', 'Networking', 'Storage', 'Desktop', 'Peripherals',
#        'Accessories'], dtype=object)

# %%
df_dim_product.segment.value_counts()
# Out:
# segment
# Accessories    92
# Notebook       88
# Peripherals    70
# Storage        27
# Desktop        12
# Networking      9
# Name: count, dtype: int64

# %%
df_dim_product.category.unique()
# Out:
# array(['Gaming Laptop', 'Personal Laptop', 'Wi fi extender',
#        'USB Flash Drives', 'External Solid State Drives',
#        'Personal Desktop', 'MotherBoard', 'Processors', 'Graphic Card',
#        'Internal HDD', 'Batteries', 'Keyboard', 'Mouse'], dtype=object)

# %%
df_dim_product.category.value_counts()
# Out:
# category
# Personal Laptop                53
# Keyboard                       40
# Mouse                          40
# Gaming Laptop                  35
# Graphic Card                   27
# Processors                     18
# External Solid State Drives    15
# MotherBoard                    15
# USB Flash Drives               12
# Personal Desktop               12
# Batteries                      12
# Internal HDD                   10
# Wi fi extender                  9
# Name: count, dtype: int64

# %%
df_dim_product.variant.unique()
# Out:
# array(['Premium Misty Green', 'Premium Black', 'Plus Cool Blue',
#        'Plus Firey Red', 'Standard Black', 'Standard Cool Blue',
#        'Standard Firey Red', 'Plus Red', 'Plus Blue', 'Plus Grey',
#        'Standard Blue', 'Standard Grey', 'Premium', 'Plus', 'Standard',
#        'Premium 2', 'Premium 1', 'Plus 2', 'Standard 3', 'Standard 2',
#        'Standard 1', 'Premium Plus'], dtype=object)

# %%
df_dim_product.variant.value_counts()
# Out:
# variant
# Plus 2                 33
# Standard               33
# Premium                33
# Standard 1             21
# Standard 2             21
# Premium 1              21
# Premium 2              21
# Plus                   21
# Premium Black          12
# Premium Misty Green    11
# Standard Grey           8
# Standard Blue           8
# Plus Grey               8
# Plus Blue               8
# Plus Red                8
# Standard Firey Red      5
# Standard Cool Blue      5
# Standard Black          5
# Standard 3              5
# Plus Firey Red          5
# Plus Cool Blue          5
# Premium Plus            1
# Name: count, dtype: int64

# %% [markdown]
# grouping the table by division='P & A'

# %%
groupby=df_dim_product.groupby('division')
groupby.get_group('P & A')
# Out:
#     product_code division      segment     category                product  \
# 136  A2021150504    P & A  Peripherals  MotherBoard           AQ MB Lito 2
# 137  A2021150503    P & A  Peripherals  MotherBoard           AQ MB Lito 2
# 138  A2020150501    P & A  Peripherals  MotherBoard           AQ MB Lito 2
# 139  A1920150404    P & A  Peripherals  MotherBoard             AQ MB Lito
# 140  A1919150403    P & A  Peripherals  MotherBoard             AQ MB Lito
# ..           ...      ...          ...          ...                    ...
# 293  A2118150106    P & A  Accessories        Mouse  AQ Master wired x1 Ms
# 294  A2118150105    P & A  Accessories        Mouse  AQ Master wired x1 Ms
# 295  A2118150104    P & A  Accessories        Mouse  AQ Master wired x1 Ms
# 296  A2118150102    P & A  Accessories        Mouse  AQ Master wired x1 Ms
# 297  A2118150101    P & A  Accessories        Mouse  AQ Master wired x1 Ms
#
#         variant
# 136     Premium
# 137      Plus 2
# ...

# %% [markdown]
# grouping the table by segment='accessories'

# %%
groupby=df_dim_product.groupby('segment')
groupby.get_group('Accessories')
# Out:
#     product_code division      segment   category                product  \
# 206  A4021150405    P & A  Accessories  Batteries               AQ Mx NB
# 207  A4021150403    P & A  Accessories  Batteries               AQ Mx NB
# 208  A4020150401    P & A  Accessories  Batteries               AQ Mx NB
# 209  A3920150305    P & A  Accessories  Batteries             AQ LION x3
# 210  A3920150303    P & A  Accessories  Batteries             AQ LION x3
# ..           ...      ...          ...        ...                    ...
# 293  A2118150106    P & A  Accessories      Mouse  AQ Master wired x1 Ms
# 294  A2118150105    P & A  Accessories      Mouse  AQ Master wired x1 Ms
# 295  A2118150104    P & A  Accessories      Mouse  AQ Master wired x1 Ms
# 296  A2118150102    P & A  Accessories      Mouse  AQ Master wired x1 Ms
# 297  A2118150101    P & A  Accessories      Mouse  AQ Master wired x1 Ms
#
#         variant
# 206     Premium
# 207      Plus 2
# 208    Standard
# 209     Premium
# ...

# %% [markdown]
# grouping the table by category='batteries'

# %%
groupby=df_dim_product.groupby('category')
groupby.get_group('Batteries')
# Out:
#     product_code division      segment   category     product   variant
# 206  A4021150405    P & A  Accessories  Batteries    AQ Mx NB   Premium
# 207  A4021150403    P & A  Accessories  Batteries    AQ Mx NB    Plus 2
# 208  A4020150401    P & A  Accessories  Batteries    AQ Mx NB  Standard
# 209  A3920150305    P & A  Accessories  Batteries  AQ LION x3   Premium
# 210  A3920150303    P & A  Accessories  Batteries  AQ LION x3    Plus 2
# 211  A3920150301    P & A  Accessories  Batteries  AQ LION x3  Standard
# 212  A3819150205    P & A  Accessories  Batteries  AQ LION x2   Premium
# 213  A3819150203    P & A  Accessories  Batteries  AQ LION x2    Plus 2
# 214  A3818150201    P & A  Accessories  Batteries  AQ LION x2  Standard
# 215  A3718150105    P & A  Accessories  Batteries  AQ LION x1   Premium
# 216  A3718150103    P & A  Accessories  Batteries  AQ LION x1    Plus 2
# 217  A3718150101    P & A  Accessories  Batteries  AQ LION x1  Standard

# %% [markdown]
# grouping the table by product='AQ Mx NB'

# %%
groupby=df_dim_product.groupby('product')
groupby.get_group('AQ Mx NB')
# Out:
#     product_code division      segment   category   product   variant
# 206  A4021150405    P & A  Accessories  Batteries  AQ Mx NB   Premium
# 207  A4021150403    P & A  Accessories  Batteries  AQ Mx NB    Plus 2
# 208  A4020150401    P & A  Accessories  Batteries  AQ Mx NB  Standard

# %% [markdown]
# grouping the table by varient='premium'

# %%
groupby=df_dim_product.groupby('variant')
groupby.get_group('Premium')
# Out:
#     product_code division      segment                     category  \
# 88   A7321160303    N & S   Networking               Wi fi extender
# 91   A7220160203    N & S   Networking               Wi fi extender
# 94   A7119160103    N & S   Networking               Wi fi extender
# 97   A7020160403    N & S      Storage             USB Flash Drives
# 100  A6918160303    N & S      Storage             USB Flash Drives
# 103  A6819160203    N & S      Storage             USB Flash Drives
# 106  A6720160103    N & S      Storage             USB Flash Drives
# 109  A6621160503    N & S      Storage  External Solid State Drives
# 112  A6520160403    N & S      Storage  External Solid State Drives
# 115  A6419160303    N & S      Storage  External Solid State Drives
# 118  A6319160203    N & S      Storage  External Solid State Drives
# 121  A6219160103    N & S      Storage  External Solid State Drives
# 136  A2021150504    P & A  Peripherals                  MotherBoard
# ...

# %%
df_dim_product.isna()
# Out:
#      product_code  division  segment  category  product  variant
# 0           False     False    False     False    False    False
# 1           False     False    False     False    False    False
# 2           False     False    False     False    False    False
# 3           False     False    False     False    False    False
# 4           False     False    False     False    False    False
# ..            ...       ...      ...       ...      ...      ...
# 293         False     False    False     False    False    False
# 294         False     False    False     False    False    False
# 295         False     False    False     False    False    False
# 296         False     False    False     False    False    False
# 297         False     False    False     False    False    False
#
# [298 rows x 6 columns]

# %%
df_dim_product.isna().sum()
# Out:
# product_code    0
# division        0
# segment         0
# category        0
# product         0
# variant         0
# dtype: int64

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# handling negative values

# %%
df_fact_sales.isna().sum()
# Out:
# date                0
# product_code        0
# customer_code       0
# Qty                 0
# net_sales_amount    0
# dtype: int64

# %% [markdown]
# handling negative values using absolute method

# %%
df_fact_sales['Qty']=df_fact_sales['Qty'].abs()
df_fact_sales
# Out:
#             date product_code  customer_code  Qty  net_sales_amount
# 0       9/1/2018  A0418150108       90023030   16            163.98
# 1       9/1/2018  A3019150205       90023023  132            698.85
# 2       9/1/2018  A3019150205       90023030  111            641.68
# 3       9/1/2018  A3019150205       90012041   59            289.60
# 4       9/1/2018  A3019150205       90014141    4             19.95
# ...          ...          ...            ...  ...               ...
# 799957  8/1/2021  A3019150205       70017060   37            260.80
# 799958  8/1/2021  A3019150205       70007199   66            390.05
# 799959  8/1/2021  A3019150205       70018115  101            507.93
# 799960  8/1/2021  A3019150205       70019204   20            129.95
# 799961  8/1/2021  A3019150205       70021096  200           1324.23
#
# [799962 rows x 5 columns]

# %%
neg_qty=df_fact_sales['Qty']<0
neg_qty.value_counts()
# Out:
# False    799962
# Name: Qty, dtype: int64

# %%
neg_amt=df_fact_sales['net_sales_amount']<0
neg_amt.value_counts()
# Out:
# net_sales_amount
# False    799962
# Name: count, dtype: int64

# %%
df_dim_customer.isna().sum()
# Out:
# customer_code    0
# customer         0
# market           0
# platform         0
# channel          0
# dtype: int64

# %% [markdown]
# handling null values

# %%
df_dim_market.isna().sum()
# Out:
# market      0
# sub_zone    2
# region      2
# dtype: int64

# %% [markdown]
# replacing the null values with 'not available'

# %%
df_dim_market.fillna('not available', inplace=True)
df_dim_market
# Out:
#             market       sub_zone         region
# 0           Canada  not available  not available
# 1              USA  not available  not available
# 2   United Kingdom             NE             EU
# 3          Austria             NE             EU
# 4           Sweden             NE             EU
# 5            Spain             SE             EU
# 6         Portugal             SE             EU
# 7           Poland             NE             EU
# 8           Norway             NE             EU
# 9      Netherlands             NE             EU
# 10           Italy             SE             EU
# 11         Germany             NE             EU
# 12          France             SE             EU
# 13      Bangladesh            ROA           APAC
# 14      Newzealand            ANZ           APAC
# 15       Australia            ANZ           APAC
# 16     South Korea            ROA           APAC
# 17     Philiphines            ROA           APAC
# ...

# %%
df_dim_product.isna().sum()
# Out:
# product_code    0
# division        0
# segment         0
# category        0
# product         0
# variant         0
# dtype: int64

# %% [markdown]
# calculating outlier limit

# %%
higher_limit=df_fact_sales['net_sales_amount'].mean()+3*df_fact_sales['net_sales_amount'].std()
higher_limit
# Out:
# 7071.318341426482

# %%
outlier=df_fact_sales['net_sales_amount']>higher_limit
outlier.value_counts()
# Out:
# net_sales_amount
# False    783382
# True      16580
# Name: count, dtype: int64

# %% [markdown]
# removing outlier values

# %%
df_fact_sales=df_fact_sales[df_fact_sales['net_sales_amount']<higher_limit]
df_fact_sales
# Out:
#             date product_code  customer_code  Qty  net_sales_amount
# 0       9/1/2018  A0418150108       90023030   16            163.98
# 1       9/1/2018  A3019150205       90023023  132            698.85
# 2       9/1/2018  A3019150205       90023030  111            641.68
# 3       9/1/2018  A3019150205       90012041   59            289.60
# 4       9/1/2018  A3019150205       90014141    4             19.95
# ...          ...          ...            ...  ...               ...
# 799957  8/1/2021  A3019150205       70017060   37            260.80
# 799958  8/1/2021  A3019150205       70007199   66            390.05
# 799959  8/1/2021  A3019150205       70018115  101            507.93
# 799960  8/1/2021  A3019150205       70019204   20            129.95
# 799961  8/1/2021  A3019150205       70021096  200           1324.23
#
# [783382 rows x 5 columns]

# %% [markdown]
# DATA TRANSFORMATION

# %%
df_fact_sales.dtypes
# Out:
# date                 object
# product_code         object
# customer_code         int64
# Qty                   int64
# net_sales_amount    float64
# dtype: object

# %% [markdown]
# changing the data type for customer code and quantity in fact table

# %%
df_fact_sales['customer_code']=pd.to_numeric(df_fact_sales['customer_code'])
df_fact_sales['Qty']=pd.to_numeric(df_fact_sales['Qty'])

# %%
df_fact_sales
# Out:
#              date product_code  customer_code  Qty  net_sales_amount
# 0      2018-09-01  A0418150108       90023030   16            163.98
# 1      2018-09-01  A3019150205       90023023  132            698.85
# 2      2018-09-01  A3019150205       90023030  111            641.68
# 3      2018-09-01  A3019150205       90012041   59            289.60
# 4      2018-09-01  A3019150205       90014141    4             19.95
# ...           ...          ...            ...  ...               ...
# 799957 2021-08-01  A3019150205       70017060   37            260.80
# 799958 2021-08-01  A3019150205       70007199   66            390.05
# 799959 2021-08-01  A3019150205       70018115  101            507.93
# 799960 2021-08-01  A3019150205       70019204   20            129.95
# 799961 2021-08-01  A3019150205       70021096  200           1324.23
#
# [799962 rows x 5 columns]

# %%
df_dim_customer.dtypes
# Out:
# customer_code     int64
# customer         object
# market           object
# platform         object
# channel          object
# dtype: object

# %%
df_dim_customer
# Out:
#      customer_code            customer       market        platform  \
# 0         80001019             Neptune        China  Brick & Mortar
# 1         70003182       Atliq e Store    Indonesia      E-Commerce
# 2         70003181     AltiQ Exclusive    Indonesia  Brick & Mortar
# 3         70007198     AltiQ Exclusive  South Korea  Brick & Mortar
# 4         70007199       Atliq e Store  South Korea      E-Commerce
# ..             ...                 ...          ...             ...
# 184       90002014          Expression        India  Brick & Mortar
# 185       90002011     Atliq Exclusive        India  Brick & Mortar
# 186       90002010                Ebay        India      E-Commerce
# 187       90002013  Electricalslytical        India  Brick & Mortar
# 188       90002012    Electricalsocity        India  Brick & Mortar
#
#          channel
# 0    Distributor
# 1         Direct
# 2         Direct
# 3         Direct
# 4         Direct
# ..           ...
# 184     Retailer
# ...

# %%
df_dim_market.dtypes
# Out:
# market      object
# sub_zone    object
# region      object
# dtype: object

# %%
df_dim_market
# Out:
#             market sub_zone region
# 0           Canada      NaN    NaN
# 1              USA      NaN    NaN
# 2   United Kingdom       NE     EU
# 3          Austria       NE     EU
# 4           Sweden       NE     EU
# 5            Spain       SE     EU
# 6         Portugal       SE     EU
# 7           Poland       NE     EU
# 8           Norway       NE     EU
# 9      Netherlands       NE     EU
# 10           Italy       SE     EU
# 11         Germany       NE     EU
# 12          France       SE     EU
# 13      Bangladesh      ROA   APAC
# 14      Newzealand      ANZ   APAC
# 15       Australia      ANZ   APAC
# 16     South Korea      ROA   APAC
# 17     Philiphines      ROA   APAC
# 18        Pakistan      ROA   APAC
# 19           Japan      ROA   APAC
# 20       Indonesia      ROA   APAC
# 21           India    India   APAC
# 22           China      ROA   APAC

# %%
df_dim_product.dtypes
# Out:
# product_code    object
# division        object
# segment         object
# category        object
# product         object
# variant         object
# dtype: object

# %%
df_dim_product
# Out:
#     product_code division      segment       category                product  \
# 0    A5721110508       PC     Notebook  Gaming Laptop             AQ Smash 2
# 1    A5721110507       PC     Notebook  Gaming Laptop             AQ Smash 2
# 2    A5721110505       PC     Notebook  Gaming Laptop             AQ Smash 2
# 3    A5721110504       PC     Notebook  Gaming Laptop             AQ Smash 2
# 4    A5721110503       PC     Notebook  Gaming Laptop             AQ Smash 2
# ..           ...      ...          ...            ...                    ...
# 293  A2118150106    P & A  Accessories          Mouse  AQ Master wired x1 Ms
# 294  A2118150105    P & A  Accessories          Mouse  AQ Master wired x1 Ms
# 295  A2118150104    P & A  Accessories          Mouse  AQ Master wired x1 Ms
# 296  A2118150102    P & A  Accessories          Mouse  AQ Master wired x1 Ms
# 297  A2118150101    P & A  Accessories          Mouse  AQ Master wired x1 Ms
#
#                  variant
# ...

# %%
customer=pd.merge(df_fact_sales,df_dim_customer,on='customer_code')
customer
# Out:
#             date product_code  customer_code  Qty  net_sales_amount  \
# 0       9/1/2018  A0418150108       90023030  -16            163.98
# 1       9/1/2018  A3019150205       90023023  132            698.85
# 2       9/1/2018  A3019150205       90023030  111            641.68
# 3       9/1/2018  A3019150205       90012041  -59            289.60
# 4       9/1/2018  A3019150205       90014141    4             19.95
# ...          ...          ...            ...  ...               ...
# 799957  8/1/2021  A3019150205       70017060   37            260.80
# 799958  8/1/2021  A3019150205       70007199   66            390.05
# 799959  8/1/2021  A3019150205       70018115  101            507.93
# 799960  8/1/2021  A3019150205       70019204   20            129.95
# 799961  8/1/2021  A3019150205       70021096 -200           1324.23
#
#              customer          market    platform   channel
# 0              Amazon          Canada  E-Commerce  Retailer
# ...

# %%
market=pd.merge(customer,df_dim_market,on='market')
market
# Out:
#             date product_code  customer_code  Qty  net_sales_amount  \
# 0       9/1/2018  A0418150108       90023030  -16            163.98
# 1       9/1/2018  A3019150205       90023023  132            698.85
# 2       9/1/2018  A3019150205       90023030  111            641.68
# 3       9/1/2018  A3019150205       90012041  -59            289.60
# 4       9/1/2018  A3019150205       90014141    4             19.95
# ...          ...          ...            ...  ...               ...
# 799957  8/1/2021  A3019150205       70017060   37            260.80
# 799958  8/1/2021  A3019150205       70007199   66            390.05
# 799959  8/1/2021  A3019150205       70018115  101            507.93
# 799960  8/1/2021  A3019150205       70019204   20            129.95
# 799961  8/1/2021  A3019150205       70021096 -200           1324.23
#
#              customer          market    platform   channel sub_zone region
# ...

# %%
product=pd.merge(market,df_dim_product,on='product_code')
product
# Out:
#             date product_code  customer_code  Qty  net_sales_amount  \
# 0       9/1/2018  A0418150108       90023030  -16            163.98
# 1       9/1/2018  A3019150205       90023023  132            698.85
# 2       9/1/2018  A3019150205       90023030  111            641.68
# 3       9/1/2018  A3019150205       90012041  -59            289.60
# 4       9/1/2018  A3019150205       90014141    4             19.95
# ...          ...          ...            ...  ...               ...
# 799957  8/1/2021  A3019150205       70017060   37            260.80
# 799958  8/1/2021  A3019150205       70007199   66            390.05
# 799959  8/1/2021  A3019150205       70018115  101            507.93
# 799960  8/1/2021  A3019150205       70019204   20            129.95
# 799961  8/1/2021  A3019150205       70021096 -200           1324.23
#
#              customer          market    platform   channel sub_zone region  \
# ...

# %%
df_sales=product
df_sales
# Out:
#             date product_code  customer_code  Qty  net_sales_amount  \
# 0       9/1/2018  A0418150108       90023030  -16            163.98
# 1       9/1/2018  A3019150205       90023023  132            698.85
# 2       9/1/2018  A3019150205       90023030  111            641.68
# 3       9/1/2018  A3019150205       90012041  -59            289.60
# 4       9/1/2018  A3019150205       90014141    4             19.95
# ...          ...          ...            ...  ...               ...
# 799957  8/1/2021  A3019150205       70017060   37            260.80
# 799958  8/1/2021  A3019150205       70007199   66            390.05
# 799959  8/1/2021  A3019150205       70018115  101            507.93
# 799960  8/1/2021  A3019150205       70019204   20            129.95
# 799961  8/1/2021  A3019150205       70021096 -200           1324.23
#
#              customer          market    platform   channel sub_zone region  \
# ...

# %% [markdown]
# INSIGHT GENERATION

# %% [markdown]
# average net sales amount in each customer

# %%
df_sales.groupby('customer')['net_sales_amount'].mean()
# Out:
# customer
# Acclaimed Stores       1586.595897
# All-Out                 304.372751
# AltiQ Exclusive        1106.967486
# Amazon                 1179.206544
# Argos (Sainsbury's)     288.830469
#                           ...
# UniEuro                 763.642468
# Vijay Sales            2540.823378
# Viveks                 2355.283479
# Zone                    803.337324
# walmart                1430.307835
# Name: net_sales_amount, Length: 68, dtype: float64

# %% [markdown]
# average net sales amount in each market

# %%
df_sales.groupby('market')['net_sales_amount'].mean()
# Out:
# market
# Australia         1034.142672
# Austria            140.797568
# Bangladesh         451.022730
# Canada             977.161146
# China             1362.933118
# France             887.439688
# Germany            433.209058
# India             1952.556703
# Indonesia         1313.356725
# Italy              430.285985
# Japan              305.185649
# Netherlands        408.981625
# Newzealand         554.880282
# Norway             586.274253
# Pakistan           493.925529
# Philiphines       1336.699441
# Poland             294.983793
# Portugal           387.608050
# South Korea       1868.394463
# Spain              434.433248
# Sweden             127.285209
# USA               1670.465493
# United Kingdom     878.767769
# Name: net_sales_amount, dtype: float64

# %% [markdown]
# average net sales amount in each platform

# %%
df_sales.groupby('platform')['net_sales_amount'].mean()
# Out:
# platform
# Brick & Mortar    859.227228
# E-Commerce        968.009234
# Name: net_sales_amount, dtype: float64

# %% [markdown]
# average net sales amount in each channel

# %%
df_sales.groupby('channel')['net_sales_amount'].mean()
# Out:
# channel
# Direct          875.939296
# Distributor    2299.430539
# Retailer        848.175398
# Name: net_sales_amount, dtype: float64

# %% [markdown]
# average net sales amount in each segment

# %%
df_sales.groupby('segment')['net_sales_amount'].mean()
# Out:
# segment
# Accessories     853.628453
# Desktop         759.011600
# Networking     1707.539051
# Notebook        925.167450
# Peripherals     718.748570
# Storage        1241.097935
# Name: net_sales_amount, dtype: float64

# %% [markdown]
# average net sales amount in each category

# %%
df_sales.groupby('category')['net_sales_amount'].mean()
# Out:
# category
# Batteries                       159.411602
# External Solid State Drives    1373.456314
# Gaming Laptop                   909.501493
# Graphic Card                    497.473978
# Internal HDD                    482.428685
# Keyboard                       1032.414610
# MotherBoard                     296.423028
# Mouse                           848.847656
# Personal Desktop                759.011600
# Personal Laptop                 935.817067
# Processors                     1522.252946
# USB Flash Drives                658.645604
# Wi fi extender                 1707.539051
# Name: net_sales_amount, dtype: float64

# %% [markdown]
# DATA VISUALIZATION

# %% [markdown]
# horizontal bar chart for average net sales amount in sub zone column

# %%
df_sales.groupby('sub_zone')['net_sales_amount'].mean().plot(kind='barh')
# Out:
# <Axes: ylabel='sub_zone'>

# %% [markdown]
# pie chart for average net sales amount in platform column

# %%
df_sales.groupby('platform')['net_sales_amount'].mean().plot(kind='pie')
# Out:
# <Axes: ylabel='net_sales_amount'>

# %% [markdown]
# vertical bar chart for average net sales amount in channel column

# %%
df_sales.groupby('channel')['net_sales_amount'].mean().plot(kind='bar',color=["orange","yellow","green"])
# Out:
# <Axes: xlabel='channel'>

# %% [markdown]
# pie chart for average net sales amount in segment column

# %%
df_sales.groupby('segment')['net_sales_amount'].mean().plot(kind='pie')
# Out:
# <Axes: ylabel='net_sales_amount'>
